# %%
import numpy as np
from bert_serving.client import BertClient
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.font_manager import FontProperties
from sklearn.manifold import TSNE

# %%
myfont = FontProperties(fname=r'C:\\Windows\\Fonts\\msjhbd.ttf')

# %%
bc = BertClient()

# %%
def get_vectors(terms):
    return list(map(lambda term: bc.encode([term])[0],terms))

# %%
def visualise_vectors(terms, vectors):
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(vectors)
    
    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])

    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(terms[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     fontproperties=myfont,
                     ha='right',
                     va='bottom')
    plt.show()

# %%
def vis(terms):
    vectors = get_vectors(terms)
    visualise_vectors(terms, vectors)

# %%
vis([
    "台湾大学",
    "臺灣大學",
    "臺大",
    "國立台灣大學",
    "国立台湾大学",
    "台灣大學",
    "台大",
    "國立台灣大學水源校區",
    "國立臺灣大學",
    "NTU",

    "国立清华大学",
    "清大",
    "台灣清華大學",
    "NTHU",
    "新竹清华大学",
    "National Tsing Hua University",
    "National Tsing Hua university",
    "台湾国立清华大学",
    "國立清華大學南大校區",
    "清華大學 (新竹)",
    "國立清華大學",
    
    "交通大學",
    "交大",
    "唐山工业专门学校",
    "鐵道部交通大學",
    "交通大学",
    
    "成功大學",
    "国立成功大学",
    "臺灣省立工學院",
    "台南工專",
    "NCKU",
    "台南工學院",
    "National Cheng Kung University",
    "臺灣省立成功大學",
    "台灣省立成功大學",
    "省立成功大學",
    "國立成功大學",
    
    "国立政治大学",
    "政治大學",
    "政大",
    "中央政治學校",
    "中央政治大学",
    "政治大学",
    "國立政治大學",
    
    "北京大學",
    "国立北京大学",
    "北京大学校",
    "國立北京大學",
    "Peking University",
    "Peking university",
    "北京大学",
    
    "中山大學",
    "国立广东大学",
    "中山大學 (廣州)",
    "广东大学",
    "SYSU",
    "國立第一中山大學",
    "第一中山大學",
    "廣東中山大學",
    "廣州中山大學",
    "國立中山大學 (廣州)",
    "中山大学",
    
    "哈佛",
    "哈佛大學",
    "Harvard university",
    "哈伐特大学",
    "美國哈佛大學",
    "美国哈佛大学",
    "Harvard University",
    "Harvard",
    "哈佛大学",
    
    "沃里克大学",
    "華威大學",
    "华威大学",
    "University of Warwick",
])
